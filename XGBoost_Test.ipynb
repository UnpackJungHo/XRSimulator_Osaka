# %% [markdown]
# <a href="https://colab.research.google.com/github/UnpackJungHo/XRSimulator_Osaka/blob/Learning_AI/XGBoost_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from xgboost import XGBRegressor
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

class WeatherPredictor:
    def __init__(self):
        self.models = {}
        self.scalers = {}
        self.label_encoders = {}
        self.sequence_length = 12  # 24에서 12로 감소 (더 최근 데이터에 집중)

    def load_and_preprocess_data(self, training=True):
        """데이터 로드 및 전처리"""
        try:
            if training:
                # 학습용 데이터 (2020-2022)
                df_2020 = pd.read_excel('2020_weather.xlsx', dtype={'DateTime(YYYYMMDDHHMI)': str})
                df_2021 = pd.read_excel('2021_weather.xlsx', dtype={'DateTime(YYYYMMDDHHMI)': str})
                df_2022 = pd.read_excel('2022_weather.xlsx', dtype={'DateTime(YYYYMMDDHHMI)': str})
                print("학습 데이터 로드 완료 (2020-2022)")
                df = pd.concat([df_2020, df_2021, df_2022], ignore_index=True)
            else:
                # 검증용 데이터 (2023)
                df = pd.read_excel('2023_weather.xlsx', dtype={'DateTime(YYYYMMDDHHMI)': str})
                print("검증 데이터 로드 완료 (2023)")

            # 전처리 수행
            df = self._basic_preprocessing(df)
            df = self._create_advanced_features(df)
            df = self._handle_outliers(df)
            df = self._handle_missing_values(df)

            return df

        except Exception as e:
            print("데이터 로드 중 오류 발생:")
            print(e)
            raise e

    def _basic_preprocessing(self, df):
        """기본 전처리 작업"""
        try:
            # DateTime 변환
            df['DateTime(YYYYMMDDHHMI)'] = pd.to_datetime(df['DateTime(YYYYMMDDHHMI)'],
                                                        format='%Y%m%d%H%M')

            # 시간 관련 특성 추가
            df['hour'] = df['DateTime(YYYYMMDDHHMI)'].dt.hour
            df['month'] = df['DateTime(YYYYMMDDHHMI)'].dt.month
            df['day'] = df['DateTime(YYYYMMDDHHMI)'].dt.day
            df['dayofweek'] = df['DateTime(YYYYMMDDHHMI)'].dt.dayofweek
            df['is_weekend'] = df['dayofweek'].isin([5, 6]).astype(int)
            df['season'] = pd.cut(df['month'], bins=[0,3,6,9,12], labels=['winter','spring','summer','fall'])

            # 순환 시간 특성
            df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
            df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
            df['month_sin'] = np.sin(2 * np.pi * df['month']/12)
            df['month_cos'] = np.cos(2 * np.pi * df['month']/12)

            # 범주형 변수 인코딩
            categorical_columns = ['WW', 'CT', 'season']
            for col in categorical_columns:
                if df[col].dtype == 'object' or df[col].dtype.name == 'category':
                    if col not in self.label_encoders:
                        self.label_encoders[col] = LabelEncoder()
                        self.label_encoders[col].fit(df[col].astype(str))
                    else:
                        # 새로운 카테고리 처리
                        unique_labels = set(df[col].astype(str).unique())
                        known_labels = set(self.label_encoders[col].classes_)
                        new_labels = unique_labels - known_labels

                        if new_labels:
                            print(f"\n{col}에서 발견된 새로운 레이블: {new_labels}")
                            for new_label in new_labels:
                                df.loc[df[col].astype(str) == new_label, col] = self.label_encoders[col].classes_[0]

                    df[col] = self.label_encoders[col].transform(df[col].astype(str))

            return df

        except Exception as e:
            print("기본 전처리 중 오류 발생:")
            print(e)
            raise e

    def _create_advanced_features(self, df):
        """고급 특성 생성"""
        # 시계열 특성
        for col in ['TA', 'WS', 'HM', 'RN', 'WD']:
            # 이동평균 (더 짧은 시간 윈도우 추가)
            df[f'{col}_MA1'] = df[col].rolling(window=1).mean()
            df[f'{col}_MA2'] = df[col].rolling(window=2).mean()
            df[f'{col}_MA3'] = df[col].rolling(window=3).mean()
            df[f'{col}_MA6'] = df[col].rolling(window=6).mean()

            # 변화율 (더 세밀한 변화 감지)
            df[f'{col}_change'] = df[col].diff()
            df[f'{col}_change_rate'] = df[col].pct_change()
            df[f'{col}_change_acc'] = df[col].diff().diff()  # 변화 가속도

            # 시간별 통계
            df[f'{col}_hour_mean'] = df.groupby('hour')[col].transform('mean')
            df[f'{col}_hour_std'] = df.groupby('hour')[col].transform('std')

            # 시간대별 특성
            morning_mask = (df['hour'] >= 6) & (df['hour'] < 12)
            afternoon_mask = (df['hour'] >= 12) & (df['hour'] < 18)
            evening_mask = (df['hour'] >= 18) & (df['hour'] < 24)
            night_mask = (df['hour'] < 6)

            df[f'{col}_morning_avg'] = df[col][morning_mask].mean()
            df[f'{col}_afternoon_avg'] = df[col][afternoon_mask].mean()
            df[f'{col}_evening_avg'] = df[col][evening_mask].mean()
            df[f'{col}_night_avg'] = df[col][night_mask].mean()

            # 일교차 관련 특성
            df[f'{col}_daily_range'] = df.groupby(df['DateTime(YYYYMMDDHHMI)'].dt.date)[col].transform(lambda x: x.max() - x.min())
            df[f'{col}_daily_max'] = df.groupby(df['DateTime(YYYYMMDDHHMI)'].dt.date)[col].transform('max')
            df[f'{col}_daily_min'] = df.groupby(df['DateTime(YYYYMMDDHHMI)'].dt.date)[col].transform('min')

            # 계절성 특성
            df[f'{col}_season_mean'] = df.groupby('season')[col].transform('mean')
            df[f'{col}_season_std'] = df.groupby('season')[col].transform('std')

        return df

    def _handle_outliers(self, df):
        """이상치 처리"""
        numerical_columns = ['TA', 'WS', 'HM', 'RN']
        for col in numerical_columns:
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            df[col] = df[col].clip(lower_bound, upper_bound)
        return df

    def _handle_missing_values(self, df):
        """결측치 처리"""
        numerical_columns = ['TA', 'WS', 'HM', 'RN']
        for col in numerical_columns:
            # 시간대별 평균으로 결측치 처리
            df[col] = df.groupby('hour')[col].transform(
                lambda x: x.fillna(x.mean())
            )
        df.fillna(df.mean(), inplace=True)
        return df

    def create_sequences(self, data, target_col):
        """시계열 시퀀스를 특성으로 변환"""
        X, y = [], []
        for i in range(len(data) - self.sequence_length):
            sequence = data.iloc[i:i + self.sequence_length].values.flatten()
            X.append(sequence)
            y.append(data[target_col].iloc[i + self.sequence_length])
        return np.array(X), np.array(y)

    def train_models(self, df):
        """XGBoost 모델 학습"""
        target_columns = ['TA', 'RN', 'WS', 'HM', 'WD']
        feature_columns = [col for col in df.columns
                         if col not in ['DateTime(YYYYMMDDHHMI)'] + target_columns]

        for target in target_columns:
            print(f"\n{target} 모델 학습 중...")

            # 데이터 준비
            data = df[feature_columns + [target]].copy()
            data = data.replace([np.inf, -np.inf], np.nan)
            data = data.fillna(data.mean())

            # 데이터 스케일링
            scaler = MinMaxScaler()
            scaled_data = scaler.fit_transform(data)
            scaled_df = pd.DataFrame(scaled_data, columns=data.columns)
            self.scalers[target] = scaler

            # 시퀀스 생성
            X, y = self.create_sequences(scaled_df, target)

            # 학습/검증 분할
            train_size = int(len(X) * 0.8)
            X_train, X_test = X[:train_size], X[train_size:]
            y_train, y_test = y[:train_size], y[train_size:]

            # XGBoost 모델 생성 및 학습
            model = XGBRegressor(
                n_estimators=200,
                max_depth=8,
                learning_rate=0.05,
                min_child_weight=3,
                subsample=0.8,
                colsample_bytree=0.8,
                random_state=42,
                n_jobs=-1,
                eval_metric='rmse',
                early_stopping_rounds=20
            )

            # eval_set 설정
            eval_set = [(X_test, y_test)]

            # 모델 학습
            model.fit(
                X_train,
                y_train,
                eval_set=eval_set,
                verbose=True
            )

            self.models[target] = model

            # 성능 평가
            y_pred = model.predict(X_test)
            mse = mean_squared_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            print(f"{target} 모델 성능:")
            print(f"MSE: {mse:.4f}")
            print(f"R2 Score: {r2:.4f}")

    def predict_and_evaluate(self, input_time, validation_data):
        """예측 수행 및 평가"""
        input_datetime = pd.to_datetime(input_time, format='%Y/%m/%d/%H:%M')

        # 입력 시퀀스 준비
        past_data = validation_data[
            validation_data['DateTime(YYYYMMDDHHMI)'] <= input_datetime
        ].tail(self.sequence_length)

        if len(past_data) < self.sequence_length:
            print(f"예측을 위해 최소 {self.sequence_length}시간의 데이터가 필요합니다.")
            return None

        predictions = []
        current_sequence = past_data.copy()

        # 예측할 변수들
        target_columns = ['TA', 'RN', 'WS', 'HM', 'WD']
        feature_columns = [col for col in current_sequence.columns
                        if col not in ['DateTime(YYYYMMDDHHMI)'] + target_columns]

        for hour in range(6):
            next_time = input_datetime + timedelta(hours=hour)

            hour_prediction = {
                'DateTime': next_time
            }

            # 각 타겟 변수에 대한 예측
            for target in target_columns:
                # 입력 데이터 준비
                data = current_sequence[feature_columns + [target]].copy()
                data = data.replace([np.inf, -np.inf], np.nan)
                data = data.fillna(data.mean())

                # 스케일링
                scaler = self.scalers[target]
                scaled_sequence = scaler.transform(data)

                # 시퀀스를 1차원으로 평탄화
                X = scaled_sequence.flatten().reshape(1, -1)

                # 예측
                scaled_pred = self.models[target].predict(X)[0]

                # 역스케일링을 위한 더미 데이터 생성
                dummy_data = np.zeros((1, data.shape[1]))
                dummy_data[0, -1] = scaled_pred
                pred = scaler.inverse_transform(dummy_data)[0, -1]

                # 시간대별 보정
                hour_of_day = (next_time.hour)
                if 6 <= hour_of_day < 12:  # 아침
                    pred = pred * 1.1  # 아침 시간대 가중치
                elif 12 <= hour_of_day < 18:  # 오후
                    pred = pred * 1.05  # 오후 시간대 가중치
                elif 18 <= hour_of_day < 24:  # 저녁
                    pred = pred * 0.95  # 저녁 시간대 가중치
                else:  # 새벽
                    pred = pred * 0.9  # 새벽 시간대 가중치

                hour_prediction[f'{target}_pred'] = pred

                # 실제값 찾기
                actual_row = validation_data[
                    validation_data['DateTime(YYYYMMDDHHMI)'] == next_time
                ]
                if not actual_row.empty:
                    hour_prediction[f'{target}_actual'] = actual_row[target].iloc[0]
                else:
                    hour_prediction[f'{target}_actual'] = None

            predictions.append(hour_prediction)

            # 시퀀스 업데이트 시 가중치 적용
            new_row = current_sequence.iloc[-1:].copy()
            for target in target_columns:
                if hour > 0:
                    weight = max(1 - (hour * 0.1), 0.5)  # 시간이 지날수록 가중치 감소
                    prev_actual = validation_data[
                        validation_data['DateTime(YYYYMMDDHHMI)'] == (next_time - timedelta(hours=1))
                    ][target].iloc[0] if not validation_data[
                        validation_data['DateTime(YYYYMMDDHHMI)'] == (next_time - timedelta(hours=1))
                    ].empty else hour_prediction[f'{target}_pred']
                    new_row[target] = (weight * prev_actual + (1-weight) * hour_prediction[f'{target}_pred'])
                else:
                    new_row[target] = hour_prediction[f'{target}_pred']

            current_sequence = pd.concat([current_sequence[1:], new_row])

        results_df = pd.DataFrame(predictions)

        # 예측 성능 평가
        print("\n예측 성능 평가:")
        for target in target_columns:
            mask = results_df[f'{target}_actual'].notna()
            if mask.any():
                mae = mean_absolute_error(
                    results_df[mask][f'{target}_actual'],
                    results_df[mask][f'{target}_pred']
                )
                mse = mean_squared_error(
                    results_df[mask][f'{target}_actual'],
                    results_df[mask][f'{target}_pred']
                )
                r2 = r2_score(
                    results_df[mask][f'{target}_actual'],
                    results_df[mask][f'{target}_pred']
                )

                print(f"\n{target} 예측 성능:")
                print(f"MAE: {mae:.4f}")
                print(f"MSE: {mse:.4f}")
                print(f"R2 Score: {r2:.4f}")

        return results_df

def main():
    # 예측기 인스턴스 생성
    predictor = WeatherPredictor()

    # 학습 데이터 로드 및 전처리
    print("학습 데이터 로드 및 전처리 중...")
    train_df = predictor.load_and_preprocess_data(training=True)

    # 모델 학습
    print("\n모델 학습 시작...")
    predictor.train_models(train_df)

    # 검증 데이터 로드
    print("\n검증 데이터 로드 중...")
    validation_df = predictor.load_and_preprocess_data(training=False)

    while True:
        # 사용자로부터 날짜 입력 받기
        input_time = input("\n예측할 날짜와 시간을 입력하세요 (형식: YYYY/MM/DD/HH:MM, 종료는 'q'): ")

        if input_time.lower() == 'q':
            break

        try:
            # 예측 수행 및 평가
            results = predictor.predict_and_evaluate(input_time, validation_df)

            if results is not None:
                print("\n예측 결과:")
                pd.set_option('display.max_columns', None)
                print(results[['DateTime'] +
                            [col for col in results.columns if 'pred' in col or 'actual' in col]])

        except Exception as e:
            print(f"오류 발생: {str(e)}")
            print("올바른 형식으로 다시 입력해주세요.")

if __name__ == "__main__":
    main()
# Out:
# 학습 데이터 로드 및 전처리 중...
# 학습 데이터 로드 완료 (2020-2022)
#
# 모델 학습 시작...
#
# TA 모델 학습 중...
# [0]	validation_0-rmse:0.20381
# [1]	validation_0-rmse:0.19374
# [2]	validation_0-rmse:0.18416
# [3]	validation_0-rmse:0.17506
# [4]	validation_0-rmse:0.16636
# [5]	validation_0-rmse:0.15814
# [6]	validation_0-rmse:0.15031
# [7]	validation_0-rmse:0.14288
# [8]	validation_0-rmse:0.13584
# [9]	validation_0-rmse:0.12917
# [10]	validation_0-rmse:0.12280
# [11]	validation_0-rmse:0.11673
# [12]	validation_0-rmse:0.11100
# [13]	validation_0-rmse:0.10554
# [14]	validation_0-rmse:0.10034
# [15]	validation_0-rmse:0.09539
# [38]	validation_0-rmse:0.11014
# [39]	validation_0-rmse:0.10988
# [40]	validation_0-rmse:0.10971
# [41]	validation_0-rmse:0.10955
# [42]	validation_0-rmse:0.10942
# [43]	validation_0-rmse:0.10926
# [44]	validation_0-rmse:0.10911
# [45]	validation_0-rmse:0.10899
# [46]	validation_0-rmse:0.10889
# [47]	validation_0-rmse:0.10881
# [48]	validation_0-rmse:0.10870
# [49]	validation_0-rmse:0.10862
# [50]	validation_0-rmse:0.10852
# [51]	validation_0-rmse:0.10842
# [52]	validation_0-rmse:0.10834
# [53]	validation_0-rmse:0.10828
# [54]	validation_0-rmse:0.10820
# [55]	validation_0-rmse:0.10816
# [56]	validation_0-rmse:0.10813
# [57]	validation_0-rmse:0.10808
# [58]	validation_0-rmse:0.10802
# [59]	validation_0-rmse:0.10798
# [60]	validation_0-rmse:0.10797
# [61]	validation_0-rmse:0.10797
# [62]	validation_0-rmse:0.10798
# [63]	validation_0-rmse:0.10793
# [64]	validation_0-rmse:0.10791
# [65]	validation_0-rmse:0.10789
# [66]	validation_0-rmse:0.10785
# [67]	validation_0-rmse:0.10782
# [68]	validation_0-rmse:0.10779
# [69]	validation_0-rmse:0.10776
# [70]	validation_0-rmse:0.10774
# [71]	validation_0-rmse:0.10775
# [72]	validation_0-rmse:0.10773
# [73]	validation_0-rmse:0.10770
# [74]	validation_0-rmse:0.10766
# [75]	validation_0-rmse:0.10766
# [76]	validation_0-rmse:0.10764
# [77]	validation_0-rmse:0.10763
# [78]	validation_0-rmse:0.10761
# [79]	validation_0-rmse:0.10761
# [80]	validation_0-rmse:0.10763
# [81]	validation_0-rmse:0.10762
# [82]	validation_0-rmse:0.10761
# [83]	validation_0-rmse:0.10761
# [84]	validation_0-rmse:0.10759
# [85]	validation_0-rmse:0.10759
# [86]	validation_0-rmse:0.10758
# [87]	validation_0-rmse:0.10757
# [88]	validation_0-rmse:0.10755
# [89]	validation_0-rmse:0.10756
# [90]	validation_0-rmse:0.10754
# [91]	validation_0-rmse:0.10756
# [92]	validation_0-rmse:0.10754
# [93]	validation_0-rmse:0.10755
# [94]	validation_0-rmse:0.10754
# [95]	validation_0-rmse:0.10754
# [96]	validation_0-rmse:0.10750
# [97]	validation_0-rmse:0.10749
# [98]	validation_0-rmse:0.10751
# [99]	validation_0-rmse:0.10752
# [100]	validation_0-rmse:0.10750
# [101]	validation_0-rmse:0.10751
# [102]	validation_0-rmse:0.10752
# [103]	validation_0-rmse:0.10751
# [104]	validation_0-rmse:0.10749
# [105]	validation_0-rmse:0.10749
# [106]	validation_0-rmse:0.10750
# [107]	validation_0-rmse:0.10750
# [108]	validation_0-rmse:0.10748
# [109]	validation_0-rmse:0.10750
# [110]	validation_0-rmse:0.10750
# [111]	validation_0-rmse:0.10748
# [112]	validation_0-rmse:0.10748
# [113]	validation_0-rmse:0.10749
# [114]	validation_0-rmse:0.10749
# [115]	validation_0-rmse:0.10749
# [116]	validation_0-rmse:0.10749
# [117]	validation_0-rmse:0.10746
# [118]	validation_0-rmse:0.10747
# [119]	validation_0-rmse:0.10748
# [120]	validation_0-rmse:0.10747
# [121]	validation_0-rmse:0.10746
# [122]	validation_0-rmse:0.10745
# [123]	validation_0-rmse:0.10748
# [124]	validation_0-rmse:0.10747
# [125]	validation_0-rmse:0.10749
# [126]	validation_0-rmse:0.10749
# [127]	validation_0-rmse:0.10748
# [128]	validation_0-rmse:0.10748
# [129]	validation_0-rmse:0.10748
# [130]	validation_0-rmse:0.10747
# [131]	validation_0-rmse:0.10748
# [132]	validation_0-rmse:0.10749
# [133]	validation_0-rmse:0.10748
# [134]	validation_0-rmse:0.10750
# [135]	validation_0-rmse:0.10751
# [136]	validation_0-rmse:0.10751
# [137]	validation_0-rmse:0.10751
# [138]	validation_0-rmse:0.10751
# [139]	validation_0-rmse:0.10752
# [140]	validation_0-rmse:0.10752
# [141]	validation_0-rmse:0.10753
# [142]	validation_0-rmse:0.10753
# WS 모델 성능:
# MSE: 0.0115
# R2 Score: 0.6275
#
# HM 모델 학습 중...
# [0]	validation_0-rmse:0.19400
# [1]	validation_0-rmse:0.18470
# [2]	validation_0-rmse:0.17591
# [3]	validation_0-rmse:0.16755
# [4]	validation_0-rmse:0.15962
# [5]	validation_0-rmse:0.15220
# [6]	validation_0-rmse:0.14507
# [7]	validation_0-rmse:0.13829
# [8]	validation_0-rmse:0.13190
# [9]	validation_0-rmse:0.12581
# [10]	validation_0-rmse:0.12006
# [11]	validation_0-rmse:0.11463
# [12]	validation_0-rmse:0.10948
# [13]	validation_0-rmse:0.10461
# [14]	validation_0-rmse:0.10002
# [15]	validation_0-rmse:0.09568
# [16]	validation_0-rmse:0.09156
# [17]	validation_0-rmse:0.08770
# [18]	validation_0-rmse:0.08403
# [19]	validation_0-rmse:0.08059
# [20]	validation_0-rmse:0.07737
# [21]	validation_0-rmse:0.07430
# [22]	validation_0-rmse:0.07142
# [23]	validation_0-rmse:0.06872
# [24]	validation_0-rmse:0.06615
# [25]	validation_0-rmse:0.06375
# [26]	validation_0-rmse:0.06151
# [27]	validation_0-rmse:0.05940
# [28]	validation_0-rmse:0.05743
# [29]	validation_0-rmse:0.05559
# [30]	validation_0-rmse:0.05389
# [31]	validation_0-rmse:0.05230
# [32]	validation_0-rmse:0.05081
# [33]	validation_0-rmse:0.04943
# [34]	validation_0-rmse:0.04813
# [35]	validation_0-rmse:0.04692
# [36]	validation_0-rmse:0.04580
# [37]	validation_0-rmse:0.04478
# [38]	validation_0-rmse:0.04380
# [39]	validation_0-rmse:0.04292
# [40]	validation_0-rmse:0.04211
# [41]	validation_0-rmse:0.04136
# [42]	validation_0-rmse:0.04065
# [43]	validation_0-rmse:0.04002
# [44]	validation_0-rmse:0.03941
# [45]	validation_0-rmse:0.03884
# [46]	validation_0-rmse:0.03834
# [47]	validation_0-rmse:0.03788
# [48]	validation_0-rmse:0.03747
# [49]	validation_0-rmse:0.03708
# [50]	validation_0-rmse:0.03674
# [51]	validation_0-rmse:0.03641
# [52]	validation_0-rmse:0.03613
# [53]	validation_0-rmse:0.03583
# [54]	validation_0-rmse:0.03560
# [55]	validation_0-rmse:0.03538
# [56]	validation_0-rmse:0.03517
# [57]	validation_0-rmse:0.03499
# [58]	validation_0-rmse:0.03482
# [59]	validation_0-rmse:0.03464
# [60]	validation_0-rmse:0.03449
# [61]	validation_0-rmse:0.03436
# [62]	validation_0-rmse:0.03425
# [63]	validation_0-rmse:0.03413
# [64]	validation_0-rmse:0.03402
# [65]	validation_0-rmse:0.03393
# [66]	validation_0-rmse:0.03384
# [67]	validation_0-rmse:0.03376
# [68]	validation_0-rmse:0.03368
# [69]	validation_0-rmse:0.03361
# [70]	validation_0-rmse:0.03355
# [71]	validation_0-rmse:0.03351
# [72]	validation_0-rmse:0.03346
# [73]	validation_0-rmse:0.03340
# [74]	validation_0-rmse:0.03336
# [75]	validation_0-rmse:0.03330
# [76]	validation_0-rmse:0.03326
# [77]	validation_0-rmse:0.03322
# [78]	validation_0-rmse:0.03319
# [79]	validation_0-rmse:0.03315
# [80]	validation_0-rmse:0.03311
# [81]	validation_0-rmse:0.03308
# [82]	validation_0-rmse:0.03307
# [83]	validation_0-rmse:0.03304
# [84]	validation_0-rmse:0.03302
# [85]	validation_0-rmse:0.03300
# [86]	validation_0-rmse:0.03298
# [87]	validation_0-rmse:0.03298
# [88]	validation_0-rmse:0.03296
# [89]	validation_0-rmse:0.03295
# [90]	validation_0-rmse:0.03294
# [91]	validation_0-rmse:0.03293
# [92]	validation_0-rmse:0.03292
# [93]	validation_0-rmse:0.03290
# [94]	validation_0-rmse:0.03290
# [95]	validation_0-rmse:0.03288
# [96]	validation_0-rmse:0.03286
# [97]	validation_0-rmse:0.03285
# [98]	validation_0-rmse:0.03284
# [99]	validation_0-rmse:0.03283
# [100]	validation_0-rmse:0.03283
# [101]	validation_0-rmse:0.03282
# [102]	validation_0-rmse:0.03281
# [103]	validation_0-rmse:0.03280
# [104]	validation_0-rmse:0.03280
# [105]	validation_0-rmse:0.03278
# [106]	validation_0-rmse:0.03277
# [107]	validation_0-rmse:0.03277
# [108]	validation_0-rmse:0.03276
# [109]	validation_0-rmse:0.03275
# [110]	validation_0-rmse:0.03275
# [111]	validation_0-rmse:0.03274
# [112]	validation_0-rmse:0.03273
# [113]	validation_0-rmse:0.03273
# [114]	validation_0-rmse:0.03272
# [115]	validation_0-rmse:0.03272
# [116]	validation_0-rmse:0.03271
# [117]	validation_0-rmse:0.03271
# [118]	validation_0-rmse:0.03271
# [119]	validation_0-rmse:0.03271
# [120]	validation_0-rmse:0.03271
# [121]	validation_0-rmse:0.03270
# [122]	validation_0-rmse:0.03270
# [123]	validation_0-rmse:0.03270
# [124]	validation_0-rmse:0.03270
# [125]	validation_0-rmse:0.03270
# [126]	validation_0-rmse:0.03270
# [127]	validation_0-rmse:0.03270
# [128]	validation_0-rmse:0.03270
# [129]	validation_0-rmse:0.03269
# [130]	validation_0-rmse:0.03269
# [131]	validation_0-rmse:0.03268
# [132]	validation_0-rmse:0.03268
# [133]	validation_0-rmse:0.03267
# [134]	validation_0-rmse:0.03266
# [135]	validation_0-rmse:0.03266
# [136]	validation_0-rmse:0.03267
# [137]	validation_0-rmse:0.03267
# [138]	validation_0-rmse:0.03267
# [139]	validation_0-rmse:0.03267
# [140]	validation_0-rmse:0.03267
# [141]	validation_0-rmse:0.03267
# [142]	validation_0-rmse:0.03267
# [143]	validation_0-rmse:0.03266
# [144]	validation_0-rmse:0.03266
# [145]	validation_0-rmse:0.03266
# [146]	validation_0-rmse:0.03266
# [147]	validation_0-rmse:0.03266
# [148]	validation_0-rmse:0.03266
# [149]	validation_0-rmse:0.03265
# [150]	validation_0-rmse:0.03265
# [151]	validation_0-rmse:0.03265
# [152]	validation_0-rmse:0.03264
# [153]	validation_0-rmse:0.03265
# [154]	validation_0-rmse:0.03264
# [155]	validation_0-rmse:0.03264
# [156]	validation_0-rmse:0.03264
# [157]	validation_0-rmse:0.03264
# [158]	validation_0-rmse:0.03264
# [159]	validation_0-rmse:0.03264
# [160]	validation_0-rmse:0.03263
# [161]	validation_0-rmse:0.03264
# [162]	validation_0-rmse:0.03264
# [163]	validation_0-rmse:0.03264
# [164]	validation_0-rmse:0.03263
# [165]	validation_0-rmse:0.03263
# [166]	validation_0-rmse:0.03263
# [167]	validation_0-rmse:0.03263
# [168]	validation_0-rmse:0.03263
# [169]	validation_0-rmse:0.03263
# [170]	validation_0-rmse:0.03262
# [171]	validation_0-rmse:0.03262
# [172]	validation_0-rmse:0.03262
# [173]	validation_0-rmse:0.03262
# [174]	validation_0-rmse:0.03262
# [175]	validation_0-rmse:0.03263
# [176]	validation_0-rmse:0.03262
# [177]	validation_0-rmse:0.03262
# [178]	validation_0-rmse:0.03263
# [179]	validation_0-rmse:0.03263
# [180]	validation_0-rmse:0.03262
# [181]	validation_0-rmse:0.03262
# [182]	validation_0-rmse:0.03263
# [183]	validation_0-rmse:0.03263
# [184]	validation_0-rmse:0.03262
# [185]	validation_0-rmse:0.03263
# [186]	validation_0-rmse:0.03263
# [187]	validation_0-rmse:0.03263
# [188]	validation_0-rmse:0.03263
# [189]	validation_0-rmse:0.03263
# [190]	validation_0-rmse:0.03263
# [191]	validation_0-rmse:0.03263
# [192]	validation_0-rmse:0.03264
# HM 모델 성능:
# MSE: 0.0011
# R2 Score: 0.9702
#
# WD 모델 학습 중...
# [0]	validation_0-rmse:0.23773
# [1]	validation_0-rmse:0.23167
# [2]	validation_0-rmse:0.22603
# [3]	validation_0-rmse:0.22094
# [4]	validation_0-rmse:0.21611
# [5]	validation_0-rmse:0.21157
# [6]	validation_0-rmse:0.20745
# [7]	validation_0-rmse:0.20366
# [8]	validation_0-rmse:0.20023
# [9]	validation_0-rmse:0.19697
# [10]	validation_0-rmse:0.19404
# [11]	validation_0-rmse:0.19129
# [12]	validation_0-rmse:0.18888
# [13]	validation_0-rmse:0.18671
# [14]	validation_0-rmse:0.18473
# [15]	validation_0-rmse:0.18278
# [16]	validation_0-rmse:0.18112
# [17]	validation_0-rmse:0.17965
# [18]	validation_0-rmse:0.17815
# [19]	validation_0-rmse:0.17680
# [20]	validation_0-rmse:0.17563
# [21]	validation_0-rmse:0.17460
# [22]	validation_0-rmse:0.17356
# [23]	validation_0-rmse:0.17262
# [24]	validation_0-rmse:0.17177
# [25]	validation_0-rmse:0.17112
# [26]	validation_0-rmse:0.17041
# [27]	validation_0-rmse:0.16986
# [28]	validation_0-rmse:0.16935
# [29]	validation_0-rmse:0.16890
# [30]	validation_0-rmse:0.16843
# [31]	validation_0-rmse:0.16812
# [32]	validation_0-rmse:0.16774
# [33]	validation_0-rmse:0.16730
# [34]	validation_0-rmse:0.16700
# [35]	validation_0-rmse:0.16676
# [36]	validation_0-rmse:0.16657
# [37]	validation_0-rmse:0.16632
# [38]	validation_0-rmse:0.16613
# [39]	validation_0-rmse:0.16591
# [40]	validation_0-rmse:0.16558
# [41]	validation_0-rmse:0.16537
# [42]	validation_0-rmse:0.16527
# [43]	validation_0-rmse:0.16512
# [44]	validation_0-rmse:0.16497
# [45]	validation_0-rmse:0.16480
# [46]	validation_0-rmse:0.16466
# [47]	validation_0-rmse:0.16457
# [48]	validation_0-rmse:0.16449
# [49]	validation_0-rmse:0.16437
# [50]	validation_0-rmse:0.16427
# [51]	validation_0-rmse:0.16422
# [52]	validation_0-rmse:0.16420
# [53]	validation_0-rmse:0.16416
# [54]	validation_0-rmse:0.16414
# [55]	validation_0-rmse:0.16405
# [56]	validation_0-rmse:0.16407
# [57]	validation_0-rmse:0.16396
# [58]	validation_0-rmse:0.16392
# [59]	validation_0-rmse:0.16388
# [60]	validation_0-rmse:0.16382
# [61]	validation_0-rmse:0.16385
# [62]	validation_0-rmse:0.16386
# [63]	validation_0-rmse:0.16389
# [64]	validation_0-rmse:0.16386
# [65]	validation_0-rmse:0.16382
# [66]	validation_0-rmse:0.16381
# [67]	validation_0-rmse:0.16375
# [68]	validation_0-rmse:0.16372
# [69]	validation_0-rmse:0.16370
# [70]	validation_0-rmse:0.16366
# [71]	validation_0-rmse:0.16363
# [72]	validation_0-rmse:0.16363
# [73]	validation_0-rmse:0.16362
# [74]	validation_0-rmse:0.16362
# [75]	validation_0-rmse:0.16358
# [76]	validation_0-rmse:0.16357
# [77]	validation_0-rmse:0.16358
# [78]	validation_0-rmse:0.16358
# [79]	validation_0-rmse:0.16358
# [80]	validation_0-rmse:0.16357
# [81]	validation_0-rmse:0.16364
# [82]	validation_0-rmse:0.16368
# [83]	validation_0-rmse:0.16363
# [84]	validation_0-rmse:0.16365
# [85]	validation_0-rmse:0.16368
# [86]	validation_0-rmse:0.16367
# [87]	validation_0-rmse:0.16364
# [88]	validation_0-rmse:0.16362
# [89]	validation_0-rmse:0.16361
# [90]	validation_0-rmse:0.16360
# [91]	validation_0-rmse:0.16359
# [92]	validation_0-rmse:0.16358
# [93]	validation_0-rmse:0.16358
# [94]	validation_0-rmse:0.16355
# [95]	validation_0-rmse:0.16353
# [96]	validation_0-rmse:0.16356
# [97]	validation_0-rmse:0.16358
# [98]	validation_0-rmse:0.16356
# [99]	validation_0-rmse:0.16354
# [100]	validation_0-rmse:0.16354
# [101]	validation_0-rmse:0.16353
# [102]	validation_0-rmse:0.16350
# [103]	validation_0-rmse:0.16348
# [104]	validation_0-rmse:0.16347
# [105]	validation_0-rmse:0.16344
# [106]	validation_0-rmse:0.16345
# [107]	validation_0-rmse:0.16345
# [108]	validation_0-rmse:0.16344
# [109]	validation_0-rmse:0.16343
# [110]	validation_0-rmse:0.16345
# [111]	validation_0-rmse:0.16349
# [112]	validation_0-rmse:0.16349
# [113]	validation_0-rmse:0.16347
# [114]	validation_0-rmse:0.16347
# [115]	validation_0-rmse:0.16347
# [116]	validation_0-rmse:0.16349
# [117]	validation_0-rmse:0.16348
# [118]	validation_0-rmse:0.16351
# [119]	validation_0-rmse:0.16355
# [120]	validation_0-rmse:0.16353
# [121]	validation_0-rmse:0.16356
# [122]	validation_0-rmse:0.16359
# [123]	validation_0-rmse:0.16358
# [124]	validation_0-rmse:0.16359
# [125]	validation_0-rmse:0.16361
# [126]	validation_0-rmse:0.16363
# [127]	validation_0-rmse:0.16364
# [128]	validation_0-rmse:0.16366
# [129]	validation_0-rmse:0.16366
# WD 모델 성능:
# MSE: 0.0267
# R2 Score: 0.5498
#
# 검증 데이터 로드 중...
# 검증 데이터 로드 완료 (2023)
#
# WW에서 발견된 새로운 레이블: {'4240', '400601', '190602', '160201', '190501', '19060502', '1601', '19060201', '601', '1602'}
#
# CT에서 발견된 새로운 레이블: {'CuAcCi', 'CuCs'}
#
# 예측할 날짜와 시간을 입력하세요 (형식: YYYY/MM/DD/HH:MM, 종료는 'q'): 2023/01/05/03:00
#
# 예측 성능 평가:
#
# TA 예측 성능:
# MAE: 1.0337
# MSE: 1.4564
# R2 Score: -2.6512
#
# RN 예측 성능:
# MAE: 0.9000
# MSE: 0.8100
# R2 Score: 0.0000
#
# WS 예측 성능:
# MAE: 0.6017
# MSE: 0.4678
# R2 Score: -0.8366
#
# HM 예측 성능:
# MAE: 4.6801
# MSE: 29.0627
# R2 Score: -2.6711
#
# WD 예측 성능:
# MAE: 14.3155
# MSE: 234.1594
# R2 Score: -0.4997
#
# 예측 결과:
#              DateTime   TA_pred  TA_actual  RN_pred  RN_actual   WS_pred  \
# 0 2023-01-05 03:00:00 -3.608414       -3.7     -8.1       -9.0  1.203573
# 1 2023-01-05 04:00:00 -3.617633       -4.3     -8.1       -9.0  1.269653
# 2 2023-01-05 05:00:00 -3.482450       -4.7     -8.1       -9.0  1.250007
# 3 2023-01-05 06:00:00 -4.179831       -5.0     -9.9       -9.0  1.540670
# 4 2023-01-05 07:00:00 -4.029556       -5.3     -9.9       -9.0  1.587426
# 5 2023-01-05 08:00:00 -3.479761       -5.6     -9.9       -9.0  1.777538
#
#    WS_actual    HM_pred  HM_actual    WD_pred  WD_actual
# 0        1.5  59.689432         65  12.628276         36
# 1        1.1  58.273580         66  10.362496          5
# 2        2.3  58.683986         67  14.291422          2
# 3        2.3  72.281297         69  15.137336          2
# 4        2.5  72.168716         71  16.662721          2
# 5        2.2  70.722409         73  19.067474          2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0c10a587acb7> in <cell line: 384>()
#     383
#     384 if __name__ == "__main__":
# --> 385     main()
#
# <ipython-input-8-0c10a587acb7> in main()
#     363     while True:
#     364         # 사용자로부터 날짜 입력 받기
# --> 365         input_time = input("\n예측할 날짜와 시간을 입력하세요 (형식: YYYY/MM/DD/HH:MM, 종료는 'q'): ")
#     366
#     367         if input_time.lower() == 'q':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
